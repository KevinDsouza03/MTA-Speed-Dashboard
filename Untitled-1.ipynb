# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install streamlit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("MTA_Bus_Route_Segment_Speeds__Beginning_2023_20241015.csv",nrows=10000) #9 mil rows, maybe load just a segment

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Timestamp', 'Day of Week', 'Hour of Day', 'Route ID',
#        'Direction', 'Borough', 'Route Type', 'Stop Order', 'Timepoint Stop ID',
#        'Timepoint Stop Name', 'Timepoint Stop Latitude',
#        'Timepoint Stop Longitude', 'Next Timepoint Stop ID',
#        'Next Timepoint Stop Name', 'Next Timepoint Stop Latitude',
#        'Next Timepoint Stop Longitude', 'Road Distance', 'Average Travel Time',
#        'Average Road Speed', 'Bus Trip Count', 'Timepoint Stop Georeference',
#        'Next Timepoint Stop Georeference'],
#       dtype='object')

# %%
#Create multiple grouping dataframes for later processing
bus_route = df.groupby(['Route ID'])
borough = df.groupby(['Borough'])
route_type = df.groupby(['Route Type'])

# %%
sim33c = df['Route ID'] == "SIM33C"
sim33c = df[sim33c]
sim33c = sim33c.sort_values(by=['Timestamp'])

# %%
cols = ['Timepoint Stop Name', 'Next Timepoint Stop Name']
for i in cols:
   print(sim33c[i].value_counts())
# Out:
# Timepoint Stop Name
# GREENWICH ST/BATTERY PL    96
# Name: count, dtype: int64
# Next Timepoint Stop Name
# E 23 ST/BROADWAY    96
# Name: count, dtype: int64

# %%
sim33c
# Out:
#       Year  Month               Timestamp Day of Week  Hour of Day Route ID  \
# 9637  2023      9  09/01/2023 01:00:00 AM   Wednesday            1      B12
# 9643  2023      9  09/01/2023 01:00:00 PM   Wednesday           13      B12
# 9529  2023      9  09/01/2023 02:00:00 AM   Wednesday            2      B12
# 9640  2023      9  09/01/2023 02:00:00 PM   Wednesday           14      B12
# 9867  2023      9  09/01/2023 03:00:00 AM     Tuesday            3      B12
# ...    ...    ...                     ...         ...          ...      ...
# 7633  2023     11  11/01/2023 10:00:00 PM   Wednesday           22      B12
# 7359  2023     11  11/01/2023 11:00:00 AM   Wednesday           11      B12
# 7373  2023     11  11/01/2023 11:00:00 PM   Wednesday           23      B12
# 7698  2023     11  11/01/2023 12:00:00 AM   Wednesday            0      B12
# 7308  2023     11  11/01/2023 12:00:00 PM   Wednesday           12      B12
#
# ...
