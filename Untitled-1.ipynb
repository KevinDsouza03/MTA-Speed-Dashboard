# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install streamlit
# Out:
# Requirement already satisfied: pandas in c:\users\dsouz\.julia\conda\3\lib\site-packages (2.2.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\dsouz\.julia\conda\3\lib\site-packages (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\dsouz\.julia\conda\3\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=8 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (5.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting streamlit
#   Downloading streamlit-1.12.0-py2.py3-none-any.whl (9.1 MB)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting cachetools>=4.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-cp39-cp39-win_amd64.whl (904 kB)
# Collecting rich>=10.11.0
#   Downloading rich-13.8.1-py3-none-any.whl (241 kB)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-17.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
# Requirement already satisfied: tornado>=5.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (6.1)
# Collecting validators>=0.2
#   Downloading validators-0.34.0-py3-none-any.whl (43 kB)
# Collecting altair>=3.2.0
#   Downloading altair-5.4.1-py3-none-any.whl (658 kB)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (4.8.2)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: packaging>=14.1 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (10.4.0)
# Collecting watchdog
#   Downloading watchdog-5.0.3-py3-none-win_amd64.whl (79 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (4.12.2)
# Collecting pympler>=0.9
#   Downloading Pympler-1.1-py3-none-any.whl (165 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Requirement already satisfied: numpy in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (2.0.1)
# Requirement already satisfied: requests>=2.4 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (2.26.0)
# Collecting toml
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting click>=7.0
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting semver
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: python-dateutil in c:\users\dsouz\.julia\conda\3\lib\site-packages (from streamlit) (2.8.2)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Collecting narwhals>=1.5.2
#   Downloading narwhals-1.8.4-py3-none-any.whl (174 kB)
# Requirement already satisfied: jinja2 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from altair>=3.2.0->streamlit) (3.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from altair>=3.2.0->streamlit) (4.2.1)
# Requirement already satisfied: colorama in c:\users\dsouz\.julia\conda\3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from pandas>=0.21.0->streamlit) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from pandas>=0.21.0->streamlit) (2024.1)
# Requirement already satisfied: pywin32>=226 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from pympler>=0.9->streamlit) (302)
# Requirement already satisfied: six>=1.5 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from requests>=2.4->streamlit) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from requests>=2.4->streamlit) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from requests>=2.4->streamlit) (2.0.8)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dsouz\.julia\conda\3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: smmap, mdurl, pygments, narwhals, markdown-it-py, gitdb, watchdog, validators, tzlocal, toml, semver, rich, pympler, pydeck, pyarrow, protobuf, gitpython, click, cachetools, blinker, altair, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.10.0
#     Uninstalling Pygments-2.10.0:
#       Successfully uninstalled Pygments-2.10.0
# Successfully installed altair-5.4.1 blinker-1.8.2 cachetools-5.5.0 click-8.1.7 gitdb-4.0.11 gitpython-3.1.43 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.8.4 protobuf-3.20.3 pyarrow-17.0.0 pydeck-0.9.1 pygments-2.18.0 pympler-1.1 rich-13.8.1 semver-3.0.2 smmap-5.0.1 streamlit-1.12.0 toml-0.10.2 tzlocal-5.2 validators-0.34.0 watchdog-5.0.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st

df = pd.read_csv("MTA_Bridges___Tunnels_Hourly_Traffic_Rates__Beginning_2010.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_73504/423072130.py in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import streamlit as st
#       5
#       6 df = pd.read_csv("MTA_Bridges___Tunnels_Hourly_Traffic_Rates__Beginning_2010.csv")
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
df.head()
# Out:
#    Plaza ID        Date  Hour Direction  # Vehicles - E-ZPass  \
# 0        23  09/21/2024    19         O                  3768
# 1        23  09/21/2024    19         I                  3168
# 2        23  09/21/2024    18         O                  3680
# 3        23  09/21/2024    18         I                  2991
# 4        23  09/21/2024    17         O                  3654
#
#    # Vehicles - VToll
# 0                 723
# 1                 643
# 2                 777
# 3                 662
# 4                 798
