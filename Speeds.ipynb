# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install streamlit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("Speeds.csv",nrows=10000) #9 mil rows, maybe load just a segment

# %%
df.head()
# Out:
#    Year  Month               Timestamp Day of Week  Hour of Day Route ID  \
# 0  2023     10  10/01/2023 09:00:00 PM    Thursday           21      B84
# 1  2023     10  10/01/2023 09:00:00 AM    Thursday            9     BXM1
# 2  2023     10  10/01/2023 02:00:00 PM    Thursday           14      M11
# 3  2023     10  10/01/2023 10:00:00 AM    Thursday           10      B84
# 4  2023     10  10/01/2023 08:00:00 AM    Thursday            8       M5
#
#   Direction    Borough Route Type  Stop Order  ...  Next Timepoint Stop ID  \
# 0         S   Brooklyn      Local           1  ...                  300590
# 1         N      Bronx    Express          13  ...                  984006
# 2         S  Manhattan      Local           7  ...                  401459
# 3         S   Brooklyn      Local           1  ...                  300590
# 4         N  Manhattan    Limited          43  ...                  400619
#
#   Next Timepoint Stop Name  Next Timepoint Stop Latitude  \
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Timestamp', 'Day of Week', 'Hour of Day', 'Route ID',
#        'Direction', 'Borough', 'Route Type', 'Stop Order', 'Timepoint Stop ID',
#        'Timepoint Stop Name', 'Timepoint Stop Latitude',
#        'Timepoint Stop Longitude', 'Next Timepoint Stop ID',
#        'Next Timepoint Stop Name', 'Next Timepoint Stop Latitude',
#        'Next Timepoint Stop Longitude', 'Road Distance', 'Average Travel Time',
#        'Average Road Speed', 'Bus Trip Count', 'Timepoint Stop Georeference',
#        'Next Timepoint Stop Georeference'],
#       dtype='object')

# %%
#Create multiple grouping dataframes for later processing
bus_route = df.groupby(['Route ID'])
borough = df.groupby(['Borough'])
route_type = df.groupby(['Route Type'])

# %%
sim33c = df['Route ID'] == "SIM33C"
sim33c = df[sim33c]

# %%
sim33c['Timestamp']
# Out:
# 6934    10/01/2023 01:00:00 PM
# 6940    10/01/2023 04:00:00 PM
# 6971    10/01/2023 11:00:00 AM
# 7002    10/01/2023 05:00:00 PM
# 7006    10/01/2023 10:00:00 AM
#                  ...
# 9975    09/01/2023 10:00:00 AM
# 9983    09/01/2023 01:00:00 PM
# 9984    09/01/2023 08:00:00 PM
# 9989    09/01/2023 03:00:00 PM
# 9999    09/01/2023 11:00:00 AM
# Name: Timestamp, Length: 96, dtype: object

# %%
temp = sim33c.sort_values(by=['Timestamp'])

# %%
temp
# Out:
#        Year  Month               Timestamp Day of Week  Hour of Day Route ID  \
# 11126  2023      4  04/01/2023 01:00:00 PM     Tuesday           13   SIM33C
# 11394  2023      4  04/01/2023 02:00:00 PM     Tuesday           14   SIM33C
# 11350  2023      4  04/01/2023 03:00:00 PM     Tuesday           15   SIM33C
# 11398  2023      4  04/01/2023 04:00:00 PM     Tuesday           16   SIM33C
# 11185  2023      4  04/01/2023 05:00:00 PM     Tuesday           17   SIM33C
# ...     ...    ...                     ...         ...          ...      ...
# 10990  2023     11  11/01/2023 10:00:00 PM      Friday           22   SIM33C
# 11014  2023     11  11/01/2023 11:00:00 AM      Friday           11   SIM33C
# 7554   2023     11  11/01/2023 11:00:00 AM   Wednesday           11   SIM33C
# 10830  2023     11  11/01/2023 12:00:00 PM      Friday           12   SIM33C
# 7573   2023     11  11/01/2023 12:00:00 PM   Wednesday           12   SIM33C
#
# ...

# %%
# Out:
# 10000
